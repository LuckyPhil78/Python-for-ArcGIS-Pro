# %%
import os, glob
from PyPDF2 import  PdfFileMerger, PdfFileReader
arcpy.env.overwriteOutput = True

# %%
# Project gdb and folder locations
projectGDB = r"C:\PythonBook\Chapter12\Chapter12.gdb"
projectFolder = "\\".join(projectGDB.split("\\")[:-1])

# bus and census data that already exists in the project gdb
busLines = os.path.join(projectGDB,"Summer21RouteShape")
censusPoly = os.path.join(projectGDB,"AlamedaContraCostaCounty_RaceHispanic_BlockGroup")
newBusLines = os.path.join(projectGDB,"AC_Transit_AdditionalTransbay")

# summary stat table to be created for the reference community calculations
sumStatTable = os.path.join(projectGDB,"SummStat_RaceHispanic_StudyArea")

# Feature layers created for selections
studyAreaFL = "SelectedCensus_FL"
busLinesFL = "SelectedBusLines_FL"
newBusCBGs = "NewBusCBGsRefComm"

# Suspended bus route and data created for suspended bus route
busRoute = "C"
newBusLinesSel = os.path.join(projectGDB,"NewTransbayLine_{0}".format(busRoute))
cbgStudyArea = os.path.join(projectGDB,"CBG_StudyArea_Bus_{0}".format(busRoute))

# Project and map and layout object for the map, inset map, and map frames for map and inset map
project = arcpy.mp.ArcGISProject("CURRENT")
m = project.listMaps("Map")[0]
inset = project.listMaps("Inset")[0]
layout = project.listLayouts("Layout")[0]
mf = layout.listElements("mapframe_element","Map Frame")[0]
mfInset = layout.listElements("mapframe_element","Inset")[0]

# table header, table box, title text elements, and legend element
tableHeader = layout.listElements("TEXT_ELEMENT","DetailsHeader")[0]
tableBox = layout.listElements("TEXT_ELEMENT","DetailsBox")[0]
title = layout.listElements("TEXT_ELEMENT","Title")[0]
legend = layout.listElements("LEGEND_ELEMENT","Legend")[0]

# %%
with arcpy.EnvManager(addOutputsToMap=False):
    arcpy.management.MakeFeatureLayer(censusPoly,studyAreaFL)
    arcpy.management.MakeFeatureLayer(busLines,busLinesFL,"PUB_RTE IN ('W', 'V', 'U', 'P', 'O', 'NX', 'NL', 'LA', 'L', 'J', 'G', 'F', 'DB1', 'DB')")
    arcpy.management.SelectLayerByLocation(studyAreaFL,"INTERSECT",busLinesFL,"0.5 Miles")
    summStats = []
    for field in arcpy.ListFields(studyAreaFL):
        if field.type == "Integer":
            print("Added {0} field name to summary stat list".format(field.name))
            summStats.append([field.name,"SUM"])
    arcpy.analysis.Statistics(studyAreaFL,sumStatTable,summStats)
# Out:
# Added total_pop field name to summary stat list
# Added white field name to summary stat list
# Added black field name to summary stat list
# Added am_indian_nat_alaska field name to summary stat list
# Added asian field name to summary stat list
# Added nat_hawaiian_pac_island field name to summary stat list
# Added some_other field name to summary stat list
# Added two_or_more field name to summary stat list
# Added hispanic_latino field name to summary stat list
# Added total_minority field name to summary stat list

# %%
arcpy.management.AddField(sumStatTable,"MinorityRefComm_Prct","FLOAT")

for f in arcpy.ListFields(sumStatTable):
    print(f.name)
    if f.name.find("minority") != -1:
        print("Minority find value is {0} for field {1}".format(str(f.name.find("minority")),f.name))
        numerField = f.name
    if f.name.find("pop") != -1:
        print("Pop find value is {0} for field {1}".format(str(f.name.find("pop")),f.name))
        denomField = f.name
arcpy.management.CalculateField(sumStatTable,"MinorityRefComm_Prct","(!{0}!/!{1}!)*100".format(numerField,denomField))

with arcpy.da.SearchCursor(sumStatTable,["MinorityRefComm_Prct"]) as cursor:
    row = next(cursor)
    refCommPrct = row[0]

print("Reference Community Number is {0}".format(str(refCommPrct)))
# Out:
# OBJECTID
# FREQUENCY
# SUM_total_pop
# Pop find value is 10 for field SUM_total_pop
# SUM_white
# SUM_black
# SUM_am_indian_nat_alaska
# SUM_asian
# SUM_nat_hawaiian_pac_island
# SUM_some_other
# SUM_two_or_more
# SUM_hispanic_latino
# SUM_total_minority
# Minority find value is 10 for field SUM_total_minority
# MinorityRefComm_Prct
# Reference Community Number is 65.56812286376953

# %%
with arcpy.EnvManager(addOutputsToMap=False):
    arcpy.analysis.Select(newBusLines,newBusLinesSel,"route_s_nm = '{0}'".format(busRoute))
    arcpy.management.MakeFeatureLayer(censusPoly,newBusCBGs)
    arcpy.management.SelectLayerByLocation(newBusCBGs,"INTERSECT",newBusLinesSel,"0.5 Miles")
    arcpy.management.SelectLayerByAttribute(newBusCBGs,"REMOVE_FROM_SELECTION","total_pop = 0")
    minorityGEOIDs = []
    allGEOIDs = []
    with arcpy.da.SearchCursor(newBusCBGs,["GEOID","percent_minority"]) as cursor:
        for row in cursor:
            allGEOIDs.append(row[0])
            if row[1] >= refCommPrct:
                minorityGEOIDs.append(row[0])
                print("Added {0} to minority GEOID list".format(row[0]))

    cbgStudyAreaTuple = tuple(allGEOIDs)
    cgbStudyAreaSQL = "GEOID in {0}".format(cbgStudyAreaTuple)
    print(cgbStudyAreaSQL)
    arcpy.analysis.Select(censusPoly,cbgStudyArea,cgbStudyAreaSQL)
# Out:
# Added 060014036001 to minority GEOID list
# Added 060014013001 to minority GEOID list
# Added 060014015001 to minority GEOID list
# Added 060014014001 to minority GEOID list
# Added 060014014002 to minority GEOID list
# Added 060014016001 to minority GEOID list
# Added 060014017003 to minority GEOID list
# Added 060014010001 to minority GEOID list
# Added 060014010002 to minority GEOID list
# Added 060014010004 to minority GEOID list
# Added 060014011003 to minority GEOID list
# Added 060014251041 to minority GEOID list
# Added 060014035013 to minority GEOID list
# Added 060014251031 to minority GEOID list
# Added 060014251022 to minority GEOID list
# Added 060014251023 to minority GEOID list
# GEOID in ('060014036001', '060014012003', '060014011004', '060014012001', '060014012002', '060014013001', '060014015001', '060014014001', '060014014002', '060014015002', '060014015003', '060014016001', '060014042002', '060014039001', '060014039003', '060014040001', '060014040002', '060014017001', '060014017003', '060014261004', '060014261006', '060014262002', '060014262001', '060014262003', '060014261005', '060014041011', '060014041012', '060014251042', '060014043003', '060014261001', '060014042003', '060014003002', '060014011001', '060014009002', '060014010001', '060014010002', '060014010003', '060014010004', '060014010005', '060014010006', '060014011003', '060014251041', '060014035012', '060014035013', '060014041021', '060014035022', '060014041022', '060014251011', '060014251031', '060014251022', '060014251023', '060014251032', '060014251012', '060014251033', '060014251021', '060014261002', '060014011002', '060014007004')

# %%
m.addDataFromPath(cbgStudyArea)
cbgStudyAreaLyr = m.listLayers("CBG_StudyArea_Bus_{0}".format(busRoute))[0]
cbgStudyAreaLyrSym = cbgStudyAreaLyr.symbology
cbgStudyAreaLyrSym.updateRenderer('GraduatedColorsRenderer')
cbgStudyAreaLyrSym.renderer.classificationField = "percent_minority"
cbgStudyAreaLyrSym.renderer.breakCount = 2
breakValue = refCommPrct
firstVal = 0
for brk in cbgStudyAreaLyrSym.renderer.classBreaks:
    brk.upperBound = breakValue
    if firstVal == 0:
        brk.label = "Minority Population > Reference Community"
        brk.symbol.color = {'RGB' : [255, 0, 0, 30]}
        brk.symbol.outlineColor = {'RGB' : [255, 0, 0, 50]}
    else:
        brk.label = "Minority Population < Reference Community"
        brk.symbol.color = {'RGB' : [0, 255, 0, 30]}
        brk.symbol.outlineColor = {'RGB' : [0, 255, 0, 50]}
    breakValue = 100
    firstVal += 1
cbgStudyAreaLyr.symbology = cbgStudyAreaLyrSym

# %%
m.addDataFromPath(newBusLinesSel)
newBusLyr = m.listLayers("NewTransbayLine_{0}".format(busRoute))[0]
newBusLyrSym = newBusLyr.symbology
newBusLyrSym.renderer.symbol.color = {"RGB" : [169, 0, 230, 100]}
newBusLyrSym.renderer.symbol.size = 1.5
newBusLyr.symbology = newBusLyrSym
newBusLyr.name = "Transbay Bus Route"

# %%
curInsetLayers = [l.name for l in inset.listLayers()]
if cbgStudyAreaLyr.name in curInsetLayers:
    insetCBGLyr = inset.listLayers(cbgStudyAreaLyr.name)[0]
    inset.removeLayer(insetCBGLyr)
    print("Removing old CBG Study Area Layer to Inset")
    inset.addLayer(cbgStudyAreaLyr)
    print("Adding new CBG Study Area Layer to Inset")
else:
    inset.addLayer(cbgStudyAreaLyr)
    print("Adding new CBG Study Area Layer to Inset")
if newBusLyr.name in curInsetLayers:
    insetBusLyr = inset.listLayers(newBusLyr.name)[0]
    inset.removeLayer(insetBusLyr)
    print("Removing old Transbay Bus Route to Inset")
    inset.addLayer(newBusLyr)
    print("Adding new Transbay Bus Route to Inset")
else:
    inset.addLayer(newBusLyr)
    print("Adding new Transbay Bus Route to Inset")
# Out:
# Adding new CBG Study Area Layer to Inset
# Adding new Transbay Bus Route to Inset

# %%
insetStudyAreaLayer = inset.listLayers("CBG_StudyArea_Bus_{0}".format(busRoute))[0]
insetExtent = mfInset.getLayerExtent(insetStudyAreaLayer,False,True)
print(insetExtent)
mfInset.camera.setExtent(insetExtent)
mfInset.camera.scale = round((mfInset.camera.scale + 2000),0)
print(mfInset.camera.scale)
# Out:
# -122.347072470221 37.8072665294239 -122.211846529491 37.8503534704394 NaN NaN NaN NaN
# 441507.0

# %%
cbgLayerLabels = cbgStudyAreaLyr.listLabelClasses()[0]
cbgLayerLabels.expression = "$feature.GEOID"
cbgLayerLabels.visible = True
cbgStudyAreaLyr.showLabels = True

# %%
legendItemNames = [item.name for item in legend  .items]
if cbgStudyAreaLyr.name not in legendItemNames:
    legend.addItem(cbgStudyAreaLyr,"TOP")
if newBusLyr.name not in legendItemNames:
    legend.addItem(newBusLyr,"TOP")

# %%
for item in legend.items:
    if item.name in (cbgStudyAreaLyr.name,newBusLyr.name,"AlamedaContraCostaCounty_RaceHispanic_BlockGroup"):
        print('{0} is displayed in the legend'.format(item.name))
        item.visible = True   
    else:
        item.visible = False
# Out:
# Transbay Bus Route is displayed in the legend
# CBG_StudyArea_Bus_C is displayed in the legend
# AlamedaContraCostaCounty_RaceHispanic_BlockGroup is displayed in the legend

# %%
prcField = []
prcDataDict = {}
for field in arcpy.ListFields(censusPoly):
    if field.type == "Single":
        print("Added {0} field name to prcField list".format(field.name))
        prcDataDict[field.name] = field.aliasName
        prcField.append(field.name)
tableHeader.text = "Percent Race/Hispanic"
# Out:
# Added prct_white field name to prcField list
# Added prct_black field name to prcField list
# Added prct_am_indian_nat_alaska field name to prcField list
# Added prct_asian field name to prcField list
# Added prct_nat_hawiian_pac_island field name to prcField list
# Added prct_some_other field name to prcField list
# Added prct_two_or_more field name to prcField list
# Added prct_hispanic_latino field name to prcField list
# Added percent_minority field name to prcField list

# %%
cbgLayer = m.listLayers("AlamedaContraCostaCounty_RaceHispanic_BlockGroup")[0]
i = 1
for geoid in minorityGEOIDs:
    print(i)
    print(geoid)
    cbgStudyAreaLyr.definitionQuery = "GEOID <> '{0}'".format(geoid)
    cbgLayer.definitionQuery = "GEOID = '{0}'".format(geoid)
    textBox = []
    with arcpy.da.SearchCursor(censusPoly,prcField,"GEOID = '{0}'".format(geoid)) as cursor2:
        row = next(cursor2)
        j=0
        while j < len(row):
            print(cursor2.fields[j])
            print(row[j])
            if j != (len(row)-1):
                tempVal = "{0}: {1}\r\n".format(prcDataDict[cursor2.fields[j]],round(row[j],2))
                print(tempVal)
            else:
                print("the last value")
                tempVal = "{0}: {1}".format(prcDataDict[cursor2.fields[j]],round(row[j],2))
                print(tempVal)
            textBox.append(tempVal)
            j+=1
            
    tableBox.text = ""
    for text in textBox:
        tableBox.text += text
        print(text) 
    tableBox.height = 1.23
    tableBox.elementPositionY = 2.2813
        
    title.text = "Figure 2.{0}\r\nBus Route: {1}\r\nBlock Group: {2}".format(str(i),busRoute,str(geoid))
    print(title.text)
    cbgLayer.name = "Population in Block Group {0}".format(geoid) 
    
    # If scale is less than 10000 set to 10000, otherwise add 2000 and round to a whole number 
    extent = mf.getLayerExtent(cbgLayer,False,True)
    print(extent)
    mf.camera.setExtent(extent)
    print(mf.camera.scale)
    if mf.camera.scale < 10000:
        mf.camera.scale = 10000
    else:
        mf.camera.scale = round((mf.camera.scale + 2000),0)
    print(mf.camera.scale)
    pdfFigNum = str(i)
    if len(pdfFigNum) == 1:
        pdfFigNum = "0"+pdfFigNum
    layout.exportToPDF(os.path.join(projectFolder,"Figure_2_{0}_BusRoute_{1}_GEOID_{2}.pdf".format(pdfFigNum,busRoute,geoid)))
    cbgLayer.name = "AlamedaContraCostaCounty_RaceHispanic_BlockGroup" 
    i+=1
# Out:
# 1
# 060014036001
# prct_white
# 13.220000267028809
# Percent White: 13.22
#
# prct_black
# 64.58000183105469
# Percent Black: 64.58
#
# prct_am_indian_nat_alaska
# 0.0
# Percent American Indian/Native Alaskan: 0.0
#
# prct_asian
# 5.679999828338623
# Percent Asian: 5.68
#
# prct_nat_hawiian_pac_island
# 0.0
# Percent Native Hawaiian/Pacific Islander: 0.0
#
# prct_some_other
# 0.0
# Percent Some Other Race: 0.0
#
# prct_two_or_more
# 5.679999828338623
# Percent Two Or More Races: 5.68
#
# prct_hispanic_latino
# 10.829999923706055
# Percent Hispanic/Latino: 10.83
#
# percent_minority
# 86.77999877929688
# the last value
# Percent Minority: 86.78
# Percent White: 13.22
#
# Percent Black: 64.58
#
# Percent American Indian/Native Alaskan: 0.0
#
# Percent Asian: 5.68
#
# Percent Native Hawaiian/Pacific Islander: 0.0
#
# Percent Some Other Race: 0.0
#
# Percent Two Or More Races: 5.68
#
# Percent Hispanic/Latino: 10.83
#
# Percent Minority: 86.78
# Figure 2.1
# Bus Route: C
# Block Group: 060014036001
# -122.254026999746 37.810504999806 -122.248008000069 37.8190010003959 NaN NaN NaN NaN
# 7447.011491756325
# 10000.0
# 2
# 060014013001
# prct_white
# 30.709999084472656
# Percent White: 30.71
#
# prct_black
# 40.9900016784668
# Percent Black: 40.99
#
# prct_am_indian_nat_alaska
# 0.3799999952316284
# Percent American Indian/Native Alaskan: 0.38
#
# prct_asian
# 5.179999828338623
# Percent Asian: 5.18
#
# prct_nat_hawiian_pac_island
# 0.0
# Percent Native Hawaiian/Pacific Islander: 0.0
#
# prct_some_other
# 0.0
# Percent Some Other Race: 0.0
#
# prct_two_or_more
# 9.680000305175781
# Percent Two Or More Races: 9.68
#
# prct_hispanic_latino
# 13.0600004196167
# Percent Hispanic/Latino: 13.06
#
# percent_minority
# 69.29000091552734
# the last value
# Percent Minority: 69.29
# Percent White: 30.71
#
# Percent Black: 40.99
#
# Percent American Indian/Native Alaskan: 0.38
#
# Percent Asian: 5.18
#
# Percent Native Hawaiian/Pacific Islander: 0.0
#
# Percent Some Other Race: 0.0
#
# Percent Two Or More Races: 9.68
#
# Percent Hispanic/Latino: 13.06
#
# Percent Minority: 69.29
# Figure 2.2
# Bus Route: C
# Block Group: 060014013001
# -122.270040999892 37.8174489998715 -122.260006000277 37.8243849995681 NaN NaN NaN NaN
# 6079.621687966523
# 10000.0
# 3
# 060014015001
# prct_white
# 31.469999313354492
# Percent White: 31.47
#
# prct_black
# 50.95000076293945
# Percent Black: 50.95
#
# prct_am_indian_nat_alaska
# 0.0
# Percent American Indian/Native Alaskan: 0.0
#
# prct_asian
# 5.099999904632568
# Percent Asian: 5.1
#
# prct_nat_hawiian_pac_island
# 2.2699999809265137
# Percent Native Hawaiian/Pacific Islander: 2.27
#
# prct_some_other
# 0.0
# Percent Some Other Race: 0.0
#
# prct_two_or_more
# 7.179999828338623
# Percent Two Or More Races: 7.18
#
# prct_hispanic_latino
# 3.0199999809265137
# Percent Hispanic/Latino: 3.02
#
# percent_minority
# 68.52999877929688
# the last value
# Percent Minority: 68.53
# Percent White: 31.47
#
# Percent Black: 50.95
#
# Percent American Indian/Native Alaskan: 0.0
#
# Percent Asian: 5.1
#
# Percent Native Hawaiian/Pacific Islander: 2.27
#
# Percent Some Other Race: 0.0
#
# Percent Two Or More Races: 7.18
#
# Percent Hispanic/Latino: 3.02
#
# Percent Minority: 68.53
# Figure 2.3
# Bus Route: C
# Block Group: 060014015001
# -122.283643000324 37.8229340001041 -122.277371999818 37.8276889999474 NaN NaN NaN NaN
# 4167.90678178471
# 10000.0
# 4
# 060014014001
# prct_white
# 17.489999771118164
# Percent White: 17.49
#
# prct_black
# 47.0
# Percent Black: 47.0
#
# prct_am_indian_nat_alaska
# 1.2899999618530273
# Percent American Indian/Native Alaskan: 1.29
#
# prct_asian
# 13.789999961853027
# Percent Asian: 13.79
#
# prct_nat_hawiian_pac_island
# 0.0
# Percent Native Hawaiian/Pacific Islander: 0.0
#
# prct_some_other
# 0.0
# Percent Some Other Race: 0.0
#
# prct_two_or_more
# 6.96999979019165
# Percent Two Or More Races: 6.97
#
# prct_hispanic_latino
# 13.470000267028809
# Percent Hispanic/Latino: 13.47
#
# percent_minority
# 82.51000213623047
# the last value
# Percent Minority: 82.51
# Percent White: 17.49
#
# Percent Black: 47.0
#
# Percent American Indian/Native Alaskan: 1.29
#
# Percent Asian: 13.79
#
# Percent Native Hawaiian/Pacific Islander: 0.0
#
# Percent Some Other Race: 0.0
#
# Percent Two Or More Races: 6.97
#
# Percent Hispanic/Latino: 13.47
#
# Percent Minority: 82.51
# Figure 2.4
# Bus Route: C
# Block Group: 060014014001
# -122.278611000297 37.819488000371 -122.268272000153 37.8268780003195 NaN NaN NaN NaN
# 6477.567175061205
# 10000.0
# 5
# 060014014002
# prct_white
# 31.510000228881836
# Percent White: 31.51
#
# prct_black
# 22.959999084472656
# Percent Black: 22.96
#
# prct_am_indian_nat_alaska
# 0.0
# Percent American Indian/Native Alaskan: 0.0
#
# prct_asian
# 10.220000267028809
# Percent Asian: 10.22
#
# prct_nat_hawiian_pac_island
# 0.8100000023841858
# Percent Native Hawaiian/Pacific Islander: 0.81
#
# prct_some_other
# 2.690000057220459
# Percent Some Other Race: 2.69
#
# prct_two_or_more
# 10.90999984741211
# Percent Two Or More Races: 10.91
#
# prct_hispanic_latino
# 20.90999984741211
# Percent Hispanic/Latino: 20.91
#
# percent_minority
# 68.48999786376953
# the last value
# Percent Minority: 68.49
# Percent White: 31.51
#
# Percent Black: 22.96
#
# Percent American Indian/Native Alaskan: 0.0
#
# Percent Asian: 10.22
#
# Percent Native Hawaiian/Pacific Islander: 0.81
#
# Percent Some Other Race: 2.69
#
# Percent Two Or More Races: 10.91
#
# Percent Hispanic/Latino: 20.91
#
# Percent Minority: 68.49
# Figure 2.5
# Bus Route: C
# Block Group: 060014014002
# -122.277914999677 37.8187319996821 -122.270203000168 37.8246229997517 NaN NaN NaN NaN
# 5163.64667724583
# 10000.0
# 6
# 060014016001
# prct_white
# 31.190000534057617
# Percent White: 31.19
#
# prct_black
# 26.030000686645508
# Percent Black: 26.03
#
# prct_am_indian_nat_alaska
# 0.0
# Percent American Indian/Native Alaskan: 0.0
#
# prct_asian
# 8.170000076293945
# Percent Asian: 8.17
#
# prct_nat_hawiian_pac_island
# 1.350000023841858
# Percent Native Hawaiian/Pacific Islander: 1.35
#
# prct_some_other
# 0.0
# Percent Some Other Race: 0.0
#
# prct_two_or_more
# 5.320000171661377
# Percent Two Or More Races: 5.32
#
# prct_hispanic_latino
# 27.940000534057617
# Percent Hispanic/Latino: 27.94
#
# percent_minority
# 68.80999755859375
# the last value
# Percent Minority: 68.81
# Percent White: 31.19
#
# Percent Black: 26.03
#
# Percent American Indian/Native Alaskan: 0.0
#
# Percent Asian: 8.17
#
# Percent Native Hawaiian/Pacific Islander: 1.35
#
# Percent Some Other Race: 0.0
#
# Percent Two Or More Races: 5.32
#
# Percent Hispanic/Latino: 27.94
#
# Percent Minority: 68.81
# Figure 2.6
# Bus Route: C
# Block Group: 060014016001
# -122.288424999614 37.8158750001312 -122.27526499978 37.8211630002723 NaN NaN NaN NaN
# 6408.418549321367
# 10000.0
# 7
# 060014017003
# prct_white
# 20.0
# Percent White: 20.0
#
# prct_black
# 38.81999969482422
# Percent Black: 38.82
#
# prct_am_indian_nat_alaska
# 0.0
# Percent American Indian/Native Alaskan: 0.0
#
# prct_asian
# 0.0
# Percent Asian: 0.0
#
# prct_nat_hawiian_pac_island
# 0.0
# Percent Native Hawaiian/Pacific Islander: 0.0
#
# prct_some_other
# 0.0
# Percent Some Other Race: 0.0
#
# prct_two_or_more
# 0.0
# Percent Two Or More Races: 0.0
#
# prct_hispanic_latino
# 41.18000030517578
# Percent Hispanic/Latino: 41.18
#
# percent_minority
# 80.0
# the last value
# Percent Minority: 80.0
# Percent White: 20.0
#
# Percent Black: 38.82
#
# Percent American Indian/Native Alaskan: 0.0
#
# Percent Asian: 0.0
#
# Percent Native Hawaiian/Pacific Islander: 0.0
#
# Percent Some Other Race: 0.0
#
# Percent Two Or More Races: 0.0
#
# Percent Hispanic/Latino: 41.18
#
# Percent Minority: 80.0
# Figure 2.7
# Bus Route: C
# Block Group: 060014017003
# -122.346680999828 37.8076579998169 -122.290529000413 37.8369319999119 NaN NaN NaN NaN
# 27343.884435387732
# 29344.0
# 8
# 060014010001
# prct_white
# 16.1299991607666
# Percent White: 16.13
#
# prct_black
# 27.360000610351562
# Percent Black: 27.36
#
# prct_am_indian_nat_alaska
# 0.0
# Percent American Indian/Native Alaskan: 0.0
#
# prct_asian
# 2.2200000286102295
# Percent Asian: 2.22
#
# prct_nat_hawiian_pac_island
# 0.0
# Percent Native Hawaiian/Pacific Islander: 0.0
#
# prct_some_other
# 2.7799999713897705
# Percent Some Other Race: 2.78
#
# prct_two_or_more
# 18.020000457763672
# Percent Two Or More Races: 18.02
#
# prct_hispanic_latino
# 33.47999954223633
# Percent Hispanic/Latino: 33.48
#
# percent_minority
# 83.87000274658203
# the last value
# Percent Minority: 83.87
# Percent White: 16.13
#
# Percent Black: 27.36
#
# Percent American Indian/Native Alaskan: 0.0
#
# Percent Asian: 2.22
#
# Percent Native Hawaiian/Pacific Islander: 0.0
#
# Percent Some Other Race: 2.78
#
# Percent Two Or More Races: 18.02
#
# Percent Hispanic/Latino: 33.48
#
# Percent Minority: 83.87
# Figure 2.8
# Bus Route: C
# Block Group: 060014010001
# -122.2758960001 37.8334050000408 -122.265630999771 37.8376360000015 NaN NaN NaN NaN
# 4998.664084306232
# 10000.0
# 9
# 060014010002
# prct_white
# 27.06999969482422
# Percent White: 27.07
#
# prct_black
# 39.33000183105469
# Percent Black: 39.33
#
# prct_am_indian_nat_alaska
# 0.0
# Percent American Indian/Native Alaskan: 0.0
#
# prct_asian
# 3.880000114440918
# Percent Asian: 3.88
#
# prct_nat_hawiian_pac_island
# 7.150000095367432
# Percent Native Hawaiian/Pacific Islander: 7.15
#
# prct_some_other
# 0.0
# Percent Some Other Race: 0.0
#
# prct_two_or_more
# 12.970000267028809
# Percent Two Or More Races: 12.97
#
# prct_hispanic_latino
# 9.600000381469727
# Percent Hispanic/Latino: 9.6
#
# percent_minority
# 72.93000030517578
# the last value
# Percent Minority: 72.93
# Percent White: 27.07
#
# Percent Black: 39.33
#
# Percent American Indian/Native Alaskan: 0.0
#
# Percent Asian: 3.88
#
# Percent Native Hawaiian/Pacific Islander: 7.15
#
# Percent Some Other Race: 0.0
#
# Percent Two Or More Races: 12.97
#
# Percent Hispanic/Latino: 9.6
#
# Percent Minority: 72.93
# Figure 2.9
# Bus Route: C
# Block Group: 060014010002
# -122.276410000421 37.8313390000948 -122.266493999998 37.8356609997554 NaN NaN NaN NaN
# 4828.714426076357
# 10000.0
# 10
# 060014010004
# prct_white
# 23.360000610351562
# Percent White: 23.36
#
# prct_black
# 25.959999084472656
# Percent Black: 25.96
#
# prct_am_indian_nat_alaska
# 0.0
# Percent American Indian/Native Alaskan: 0.0
#
# prct_asian
# 27.440000534057617
# Percent Asian: 27.44
#
# prct_nat_hawiian_pac_island
# 0.0
# Percent Native Hawaiian/Pacific Islander: 0.0
#
# prct_some_other
# 0.0
# Percent Some Other Race: 0.0
#
# prct_two_or_more
# 0.0
# Percent Two Or More Races: 0.0
#
# prct_hispanic_latino
# 23.239999771118164
# Percent Hispanic/Latino: 23.24
#
# percent_minority
# 76.63999938964844
# the last value
# Percent Minority: 76.64
# Percent White: 23.36
#
# Percent Black: 25.96
#
# Percent American Indian/Native Alaskan: 0.0
#
# Percent Asian: 27.44
#
# Percent Native Hawaiian/Pacific Islander: 0.0
#
# Percent Some Other Race: 0.0
#
# Percent Two Or More Races: 0.0
#
# Percent Hispanic/Latino: 23.24
#
# Percent Minority: 76.64
# Figure 2.10
# Bus Route: C
# Block Group: 060014010004
# -122.27172200007 37.8270439998807 -122.266894999605 37.8314810003479 NaN NaN NaN NaN
# 3889.1703358870873
# 10000.0
# 11
# 060014011003
# prct_white
# 31.940000534057617
# Percent White: 31.94
#
# prct_black
# 4.28000020980835
# Percent Black: 4.28
#
# prct_am_indian_nat_alaska
# 0.0
# Percent American Indian/Native Alaskan: 0.0
#
# prct_asian
# 44.68000030517578
# Percent Asian: 44.68
#
# prct_nat_hawiian_pac_island
# 0.0
# Percent Native Hawaiian/Pacific Islander: 0.0
#
# prct_some_other
# 1.9800000190734863
# Percent Some Other Race: 1.98
#
# prct_two_or_more
# 4.590000152587891
# Percent Two Or More Races: 4.59
#
# prct_hispanic_latino
# 12.529999732971191
# Percent Hispanic/Latino: 12.53
#
# percent_minority
# 68.05999755859375
# the last value
# Percent Minority: 68.06
# Percent White: 31.94
#
# Percent Black: 4.28
#
# Percent American Indian/Native Alaskan: 0.0
#
# Percent Asian: 44.68
#
# Percent Native Hawaiian/Pacific Islander: 0.0
#
# Percent Some Other Race: 1.98
#
# Percent Two Or More Races: 4.59
#
# Percent Hispanic/Latino: 12.53
#
# Percent Minority: 68.06
# Figure 2.11
# Bus Route: C
# Block Group: 060014011003
# -122.268563000082 37.8230120001038 -122.261374999557 37.8270540003419 NaN NaN NaN NaN
# 3542.9402227845894
# 10000.0
# 12
# 060014251041
# prct_white
# 32.66999816894531
# Percent White: 32.67
#
# prct_black
# 30.139999389648438
# Percent Black: 30.14
#
# prct_am_indian_nat_alaska
# 0.0
# Percent American Indian/Native Alaskan: 0.0
#
# prct_asian
# 16.59000015258789
# Percent Asian: 16.59
#
# prct_nat_hawiian_pac_island
# 0.7099999785423279
# Percent Native Hawaiian/Pacific Islander: 0.71
#
# prct_some_other
# 0.7599999904632568
# Percent Some Other Race: 0.76
#
# prct_two_or_more
# 5.940000057220459
# Percent Two Or More Races: 5.94
#
# prct_hispanic_latino
# 13.1899995803833
# Percent Hispanic/Latino: 13.19
#
# percent_minority
# 67.33000183105469
# the last value
# Percent Minority: 67.33
# Percent White: 32.67
#
# Percent Black: 30.14
#
# Percent American Indian/Native Alaskan: 0.0
#
# Percent Asian: 16.59
#
# Percent Native Hawaiian/Pacific Islander: 0.71
#
# Percent Some Other Race: 0.76
#
# Percent Two Or More Races: 5.94
#
# Percent Hispanic/Latino: 13.19
#
# Percent Minority: 67.33
# Figure 2.12
# Bus Route: C
# Block Group: 060014251041
# -122.281963000192 37.8310660000959 -122.275607000263 37.8372409997724 NaN NaN NaN NaN
# 5412.581256974365
# 10000.0
# 13
# 060014035013
# prct_white
# 32.5099983215332
# Percent White: 32.51
#
# prct_black
# 59.630001068115234
# Percent Black: 59.63
#
# prct_am_indian_nat_alaska
# 0.0
# Percent American Indian/Native Alaskan: 0.0
#
# prct_asian
# 0.0
# Percent Asian: 0.0
#
# prct_nat_hawiian_pac_island
# 0.0
# Percent Native Hawaiian/Pacific Islander: 0.0
#
# prct_some_other
# 0.0
# Percent Some Other Race: 0.0
#
# prct_two_or_more
# 6.78000020980835
# Percent Two Or More Races: 6.78
#
# prct_hispanic_latino
# 1.0800000429153442
# Percent Hispanic/Latino: 1.08
#
# percent_minority
# 67.48999786376953
# the last value
# Percent Minority: 67.49
# Percent White: 32.51
#
# Percent Black: 59.63
#
# Percent American Indian/Native Alaskan: 0.0
#
# Percent Asian: 0.0
#
# Percent Native Hawaiian/Pacific Islander: 0.0
#
# Percent Some Other Race: 0.0
#
# Percent Two Or More Races: 6.78
#
# Percent Hispanic/Latino: 1.08
#
# Percent Minority: 67.49
# Figure 2.13
# Bus Route: C
# Block Group: 060014035013
# -122.260006000277 37.8196250003935 -122.254132000092 37.8245150001672 NaN NaN NaN NaN
# 4286.238462867498
# 10000.0
# 14
# 060014251031
# prct_white
# 32.0
# Percent White: 32.0
#
# prct_black
# 2.2799999713897705
# Percent Black: 2.28
#
# prct_am_indian_nat_alaska
# 0.0
# Percent American Indian/Native Alaskan: 0.0
#
# prct_asian
# 45.099998474121094
# Percent Asian: 45.1
#
# prct_nat_hawiian_pac_island
# 0.0
# Percent Native Hawaiian/Pacific Islander: 0.0
#
# prct_some_other
# 0.0
# Percent Some Other Race: 0.0
#
# prct_two_or_more
# 7.289999961853027
# Percent Two Or More Races: 7.29
#
# prct_hispanic_latino
# 13.329999923706055
# Percent Hispanic/Latino: 13.33
#
# percent_minority
# 68.0
# the last value
# Percent Minority: 68.0
# Percent White: 32.0
#
# Percent Black: 2.28
#
# Percent American Indian/Native Alaskan: 0.0
#
# Percent Asian: 45.1
#
# Percent Native Hawaiian/Pacific Islander: 0.0
#
# Percent Some Other Race: 0.0
#
# Percent Two Or More Races: 7.29
#
# Percent Hispanic/Latino: 13.33
#
# Percent Minority: 68.0
# Figure 2.14
# Bus Route: C
# Block Group: 060014251031
# -122.295037999704 37.8347200004278 -122.287671999963 37.8492339997494 NaN NaN NaN NaN
# 12721.976487059004
# 14722.0
# 15
# 060014251022
# prct_white
# 29.1299991607666
# Percent White: 29.13
#
# prct_black
# 3.2699999809265137
# Percent Black: 3.27
#
# prct_am_indian_nat_alaska
# 0.3799999952316284
# Percent American Indian/Native Alaskan: 0.38
#
# prct_asian
# 51.72999954223633
# Percent Asian: 51.73
#
# prct_nat_hawiian_pac_island
# 0.0
# Percent Native Hawaiian/Pacific Islander: 0.0
#
# prct_some_other
# 1.5399999618530273
# Percent Some Other Race: 1.54
#
# prct_two_or_more
# 5.960000038146973
# Percent Two Or More Races: 5.96
#
# prct_hispanic_latino
# 7.980000019073486
# Percent Hispanic/Latino: 7.98
#
# percent_minority
# 70.87000274658203
# the last value
# Percent Minority: 70.87
# Percent White: 29.13
#
# Percent Black: 3.27
#
# Percent American Indian/Native Alaskan: 0.38
#
# Percent Asian: 51.73
#
# Percent Native Hawaiian/Pacific Islander: 0.0
#
# Percent Some Other Race: 1.54
#
# Percent Two Or More Races: 5.96
#
# Percent Hispanic/Latino: 7.98
#
# Percent Minority: 70.87
# Figure 2.15
# Bus Route: C
# Block Group: 060014251022
# -122.297809999832 37.8380019997925 -122.291975999693 37.8440720000228 NaN NaN NaN NaN
# 5320.545942944635
# 10000.0
# 16
# 060014251023
# prct_white
# 24.360000610351562
# Percent White: 24.36
#
# prct_black
# 31.5
# Percent Black: 31.5
#
# prct_am_indian_nat_alaska
# 0.0
# Percent American Indian/Native Alaskan: 0.0
#
# prct_asian
# 29.850000381469727
# Percent Asian: 29.85
#
# prct_nat_hawiian_pac_island
# 1.4700000286102295
# Percent Native Hawaiian/Pacific Islander: 1.47
#
# prct_some_other
# 0.0
# Percent Some Other Race: 0.0
#
# prct_two_or_more
# 2.009999990463257
# Percent Two Or More Races: 2.01
#
# prct_hispanic_latino
# 10.8100004196167
# Percent Hispanic/Latino: 10.81
#
# percent_minority
# 75.63999938964844
# the last value
# Percent Minority: 75.64
# Percent White: 24.36
#
# Percent Black: 31.5
#
# Percent American Indian/Native Alaskan: 0.0
#
# Percent Asian: 29.85
#
# Percent Native Hawaiian/Pacific Islander: 1.47
#
# Percent Some Other Race: 0.0
#
# Percent Two Or More Races: 2.01
#
# Percent Hispanic/Latino: 10.81
#
# Percent Minority: 75.64
# Figure 2.16
# Bus Route: C
# Block Group: 060014251023
# -122.29678700032 37.8301069999382 -122.291015000342 37.8389029999735 NaN NaN NaN NaN
# 7709.970432715083
# 10000.0

# %%
pdfMergeObj = PdfFileMerger()

pdfFiles = glob.glob(os.path.join(projectFolder,"*BusRoute_{0}*.pdf".format(busRoute)))
for pdf in pdfFiles:
    print(pdf)
    pdfMergeObj.append(PdfFileReader(pdf,"rb"))

pdfMergeObj.write(os.path.join(projectFolder,"Figure_2_BusRoute_{0}_MinorityRace_Greater_RefComm.pdf".format(busRoute)))
# Out:
# C:\PythonBook\_TestUploadedData\Chapter12\Figure_2_01_BusRoute_C_GEOID_060014036001.pdf
# C:\PythonBook\_TestUploadedData\Chapter12\Figure_2_02_BusRoute_C_GEOID_060014013001.pdf
# C:\PythonBook\_TestUploadedData\Chapter12\Figure_2_03_BusRoute_C_GEOID_060014015001.pdf
# C:\PythonBook\_TestUploadedData\Chapter12\Figure_2_04_BusRoute_C_GEOID_060014014001.pdf
# C:\PythonBook\_TestUploadedData\Chapter12\Figure_2_05_BusRoute_C_GEOID_060014014002.pdf
# C:\PythonBook\_TestUploadedData\Chapter12\Figure_2_06_BusRoute_C_GEOID_060014016001.pdf
# C:\PythonBook\_TestUploadedData\Chapter12\Figure_2_07_BusRoute_C_GEOID_060014017003.pdf
# C:\PythonBook\_TestUploadedData\Chapter12\Figure_2_08_BusRoute_C_GEOID_060014010001.pdf
# C:\PythonBook\_TestUploadedData\Chapter12\Figure_2_09_BusRoute_C_GEOID_060014010002.pdf
# C:\PythonBook\_TestUploadedData\Chapter12\Figure_2_10_BusRoute_C_GEOID_060014010004.pdf
# C:\PythonBook\_TestUploadedData\Chapter12\Figure_2_11_BusRoute_C_GEOID_060014011003.pdf
# C:\PythonBook\_TestUploadedData\Chapter12\Figure_2_12_BusRoute_C_GEOID_060014251041.pdf
# C:\PythonBook\_TestUploadedData\Chapter12\Figure_2_13_BusRoute_C_GEOID_060014035013.pdf
# C:\PythonBook\_TestUploadedData\Chapter12\Figure_2_14_BusRoute_C_GEOID_060014251031.pdf
# C:\PythonBook\_TestUploadedData\Chapter12\Figure_2_15_BusRoute_C_GEOID_060014251022.pdf
# C:\PythonBook\_TestUploadedData\Chapter12\Figure_2_16_BusRoute_C_GEOID_060014251023.pdf

# %%
m.removeLayer(newBusLyr)
m.removeLayer(cbgStudyAreaLyr)

# %%
project = arcpy.mp.ArcGISProject("CURRENT")
mapName = "Map"
m = project.listMaps(mapName)[0]

# %%
census = "AlamedaCounty_RaceHispanic_Tract"
busRoute = "Summer21RouteShape"
vegRaster = "OaklandFVeg"

# %%
censusLyr = m.listLayers(census)[0]
busRouteLyr = m.listLayers(busRoute)[0]
vegLyr = m.listLayers(vegRaster)[0]
print(busRouteLyr)
print(censusLyr)
print(vegLyr)
# Out:
# Summer21RouteShape
# AlamedaCounty_RaceHispanic_Tract
# OaklandFVeg

# %%
censusLyrSym = censusLyr.symbology
print(hasattr(censusLyrSym,"renderer"))
print(censusLyrSym.renderer.type)
# Out:
# True
# SimpleRenderer

# %%
busRouteLyrSym = busRouteLyr.symbology
print(hasattr(busRouteLyrSym,"renderer"))
print(busRouteLyrSym.renderer.type)
# Out:
# True
# UniqueValueRenderer

# %%
vegLyrSym = vegLyr.symbology
print(hasattr(vegLyrSym,"colorizer"))
print(vegLyrSym.colorizer.type)
# Out:
# True
# RasterUniqueValueColorizer

# %%
for ramp in project.listColorRamps():
    print(ramp.name)
# Out:
# Accent (3 Classes)
# Accent (4 Classes)
# Accent (5 Classes)
# Accent (6 Classes)
# Accent (7 Classes)
# Accent (8 Classes)
# Aspect
# Basic Random
# Bathymetric Scale
# Bathymetry #1
# Bathymetry #2
# Bathymetry #3
# Bathymetry #4
# Bathymetry #5
# Black and White
# Black to White
# Blue-Brown-Red 2x2
# Blue-Brown-Red 3x3
# Blue-Brown-Red 4x4
# Blue-Green (3 Classes)
# Blue-Green (4 Classes)
# Blue-Green (5 Classes)
# Blue-Green (6 Classes)
# Blue-Green (7 Classes)
# Blue-Green (8 Classes)
# Blue-Green (9 Classes)
# Blue-Green (Continuous)
# Blue-Green-Purple 2x2
# Blue-Green-Purple 3x3
# Blue-Green-Purple 4x4
# Blue-Orange-Brown 2x2
# Blue-Orange-Brown 3x3
# Blue-Orange-Brown 4x4
# Blue-Orange-Green 2x2
# Blue-Orange-Green 3x3
# Blue-Orange-Green 4x4
# Blue-Pink-Purple 2x2
# Blue-Pink-Purple 3x3
# Blue-Pink-Purple 4x4
# Blue-Purple (3 Classes)
# Blue-Purple (4 Classes)
# Blue-Purple (5 Classes)
# Blue-Purple (6 Classes)
# Blue-Purple (7 Classes)
# Blue-Purple (8 Classes)
# Blue-Purple (9 Classes)
# Blue-Purple (Continuous)
# Blues
# Blues (3 Classes)
# Blues (4 Classes)
# Blues (5 Classes)
# Blues (6 Classes)
# Blues (7 Classes)
# Blues (8 Classes)
# Blues (9 Classes)
# Blues (Continuous)
# Brown-Green (10 Classes)
# Brown-Green (11 Classes)
# Brown-Green (3 Classes)
# Brown-Green (4 Classes)
# Brown-Green (5 Classes)
# Brown-Green (6 Classes)
# Brown-Green (7 Classes)
# Brown-Green (8 Classes)
# Brown-Green (9 Classes)
# Brown-Green (Continuous)
# Cividis
# Condition Number
# Cool Grey
# Cool Tones
# Cyan to Purple
# Cyans
# Dark 2 (3 Classes)
# Dark 2 (4 Classes)
# Dark 2 (5 Classes)
# Dark 2 (6 Classes)
# Dark 2 (7 Classes)
# Dark 2 (8 Classes)
# Dark Glazes
# Elevation #1
# Elevation #10
# Elevation #11
# Elevation #12
# Elevation #2
# Elevation #3
# Elevation #4
# Elevation #5
# Elevation #6
# Elevation #7
# Elevation #8
# Elevation #9
# Enamel
# Errors
# Grays (3 Classes)
# Grays (4 Classes)
# Grays (5 Classes)
# Grays (6 Classes)
# Grays (7 Classes)
# Grays (8 Classes)
# Grays (9 Classes)
# Grays (Continuous)
# Green Blues
# Green-Blue (3 Classes)
# Green-Blue (4 Classes)
# Green-Blue (5 Classes)
# Green-Blue (6 Classes)
# Green-Blue (7 Classes)
# Green-Blue (8 Classes)
# Green-Blue (9 Classes)
# Green-Blue (Continuous)
# Green-Blue 2x2
# Green-Blue 3x3
# Green-Blue 4x4
# Green-Pink 2x2
# Green-Pink 3x3
# Green-Pink 4x4
# Greens
# Greens (3 Classes)
# Greens (4 Classes)
# Greens (5 Classes)
# Greens (6 Classes)
# Greens (7 Classes)
# Greens (8 Classes)
# Greens (9 Classes)
# Greens (Continuous)
# Heat Map 1
# Heat Map 1 - Semitransparent
# Heat Map 2
# Heat Map 2 - Semitransparent
# Heat Map 3
# Heat Map 3 - Semitransparent
# Heat Map 4
# Heat Map 4 - Semitransparent
# Heat Map : Blue-Cyan-Green
# Heat Map : Dark Blue-Cyan
# Heat Map : Dark Blue-White
# Heat Map : Dark Blue-White- Semitransparent
# Heat Map : Dark Bronze-Yellow
# Heat Map : Dark Bronze-Yellow- Semitransparent
# Heat Map : Dark Gold-White
# Heat Map : Dark Gold-White- Semitransparent
# Heat Map : Dark Green-Yellow
# Heat Map : Dark Green-Yellow- Semitransparent
# Heat Map : Dark Magenta-Yellow
# Heat Map : Dark Magenta-Yellow- Semitransparent
# Heat Map : Dark Metal-Blue-White
# Heat Map : Dark Metal-Blue-White- Semitransparent
# Heat Map : Dark Orange-Yellow
# Heat Map : Dark Orange-Yellow- Semitransparent
# Heat Map : Dark Purple-Yellow
# Heat Map : Dark Purple-Yellow- Semitransparent
# Heat Map : Neutral Blue-White
# Heat Map : Neutral Blue-White- Semitransparent
# Heat Map : Neutral Bronze-Yellow
# Heat Map : Neutral Bronze-Yellow- Semitransparent
# Heat Map : Neutral Gold-White
# Heat Map : Neutral Gold-White- Semitransparent
# Heat Map : Neutral Green-Yellow
# Heat Map : Neutral Green-Yellow- Semitransparent
# Heat Map : Neutral Magenta-Yellow
# Heat Map : Neutral Magenta-Yellow- Semitransparent
# Heat Map : Neutral Metal-Blue-White
# Heat Map : Neutral Metal-Blue-White- Semitransparent
# Heat Map : Neutral Orange-Yellow
# Heat Map : Neutral Orange-Yellow- Semitransparent
# Heat Map : Neutral Purple-Yellow
# Heat Map : Neutral Purple-Yellow- Semitransparent
# Heat Map : Purple-Red-Yellow
# Inferno
# LAS Class Codes
# Magentas
# Magma
# Mustard-Blue-Wine 2x2
# Mustard-Blue-Wine 3x3
# Mustard-Blue-Wine 4x4
# Muted Pastels
# Olive-Blue-Green 2x2
# Olive-Blue-Green 3x3
# Olive-Blue-Green 4x4
# Orange-Pink-Purple-Green 2x2
# Orange-Pink-Purple-Green 3x3
# Orange-Pink-Purple-Green 4x4
# Orange-Purple (10 Classes)
# Orange-Purple (11 Classes)
# Orange-Purple (3 Classes)
# Orange-Purple (4 Classes)
# Orange-Purple (5 Classes)
# Orange-Purple (6 Classes)
# Orange-Purple (7 Classes)
# Orange-Purple (8 Classes)
# Orange-Purple (9 Classes)
# Orange-Purple (Continuous)
# Orange-Red (3 Classes)
# Orange-Red (4 Classes)
# Orange-Red (5 Classes)
# Orange-Red (6 Classes)
# Orange-Red (7 Classes)
# Orange-Red (8 Classes)
# Orange-Red (9 Classes)
# Orange-Red (Continuous)
# Oranges
# Oranges (3 Classes)
# Oranges (4 Classes)
# Oranges (5 Classes)
# Oranges (6 Classes)
# Oranges (7 Classes)
# Oranges (8 Classes)
# Oranges (9 Classes)
# Oranges (Continuous)
# Paired (10 Classes)
# Paired (11 Classes)
# Paired (12 Classes)
# Paired (3 Classes)
# Paired (4 Classes)
# Paired (5 Classes)
# Paired (6 Classes)
# Paired (7 Classes)
# Paired (8 Classes)
# Paired (9 Classes)
# Pastel 1 (3 Classes)
# Pastel 1 (4 Classes)
# Pastel 1 (5 Classes)
# Pastel 1 (6 Classes)
# Pastel 1 (7 Classes)
# Pastel 1 (8 Classes)
# Pastel 1 (9 Classes)
# Pastel 2 (3 Classes)
# Pastel 2 (4 Classes)
# Pastel 2 (5 Classes)
# Pastel 2 (6 Classes)
# Pastel 2 (7 Classes)
# Pastel 2 (8 Classes)
# Pastel Terra Tones
# Pastels
# Pastels Blue to Red
# Pink-Blue-Purple 1 2x2
# Pink-Blue-Purple 1 3x3
# Pink-Blue-Purple 1 4x4
# Pink-Blue-Purple 2 2x2
# Pink-Blue-Purple 2 3x3
# Pink-Blue-Purple 2 4x4
# Pink-Green (10 Classes)
# Pink-Green (11 Classes)
# Pink-Green (3 Classes)
# Pink-Green (4 Classes)
# Pink-Green (5 Classes)
# Pink-Green (6 Classes)
# Pink-Green (7 Classes)
# Pink-Green (8 Classes)
# Pink-Green (9 Classes)
# Pink-Green (Continuous)
# Plasma
# Precipitation
# Prediction
# Purple Blues
# Purple Reds
# Purple-Blue (3 Classes)
# Purple-Blue (4 Classes)
# Purple-Blue (5 Classes)
# Purple-Blue (6 Classes)
# Purple-Blue (7 Classes)
# Purple-Blue (8 Classes)
# Purple-Blue (9 Classes)
# Purple-Blue (Continuous)
# Purple-Blue-Green (3 Classes)
# Purple-Blue-Green (4 Classes)
# Purple-Blue-Green (5 Classes)
# Purple-Blue-Green (6 Classes)
# Purple-Blue-Green (7 Classes)
# Purple-Blue-Green (8 Classes)
# Purple-Blue-Green (9 Classes)
# Purple-Blue-Green (Continuous)
# Purple-Brown-Yellow 2x2
# Purple-Brown-Yellow 3x3
# Purple-Brown-Yellow 4x4
# Purple-Green (10 Classes)
# Purple-Green (11 Classes)
# Purple-Green (3 Classes)
# Purple-Green (4 Classes)
# Purple-Green (5 Classes)
# Purple-Green (6 Classes)
# Purple-Green (7 Classes)
# Purple-Green (8 Classes)
# Purple-Green (9 Classes)
# Purple-Green (Continuous)
# Purple-Green-Blue 2x2
# Purple-Green-Blue 3x3
# Purple-Green-Blue 4x4
# Purple-Green-Wine 2x2
# Purple-Green-Wine 3x3
# Purple-Green-Wine 4x4
# Purple-Orange 2x2
# Purple-Orange 3x3
# Purple-Orange 4x4
# Purple-Red (3 Classes)
# Purple-Red (4 Classes)
# Purple-Red (5 Classes)
# Purple-Red (6 Classes)
# Purple-Red (7 Classes)
# Purple-Red (8 Classes)
# Purple-Red (9 Classes)
# Purple-Red (Continuous)
# Purples
# Purples (3 Classes)
# Purples (4 Classes)
# Purples (5 Classes)
# Purples (6 Classes)
# Purples (7 Classes)
# Purples (8 Classes)
# Purples (9 Classes)
# Purples (Continuous)
# Red to Green
# Red-Blue (10 Classes)
# Red-Blue (11 Classes)
# Red-Blue (3 Classes)
# Red-Blue (4 Classes)
# Red-Blue (5 Classes)
# Red-Blue (6 Classes)
# Red-Blue (7 Classes)
# Red-Blue (8 Classes)
# Red-Blue (9 Classes)
# Red-Blue (Continuous)
# Red-Gray (10 Classes)
# Red-Gray (11 Classes)
# Red-Gray (3 Classes)
# Red-Gray (4 Classes)
# Red-Gray (5 Classes)
# Red-Gray (6 Classes)
# Red-Gray (7 Classes)
# Red-Gray (8 Classes)
# Red-Gray (9 Classes)
# Red-Gray (Continuous)
# Red-Purple (3 Classes)
# Red-Purple (4 Classes)
# Red-Purple (5 Classes)
# Red-Purple (6 Classes)
# Red-Purple (7 Classes)
# Red-Purple (8 Classes)
# Red-Purple (9 Classes)
# Red-Purple (Continuous)
# Red-Yellow-Blue (10 Classes)
# Red-Yellow-Blue (11 Classes)
# Red-Yellow-Blue (3 Classes)
# Red-Yellow-Blue (4 Classes)
# Red-Yellow-Blue (5 Classes)
# Red-Yellow-Blue (6 Classes)
# Red-Yellow-Blue (7 Classes)
# Red-Yellow-Blue (8 Classes)
# Red-Yellow-Blue (9 Classes)
# Red-Yellow-Blue (Continuous)
# Red-Yellow-Green (10 Classes)
# Red-Yellow-Green (11 Classes)
# Red-Yellow-Green (3 Classes)
# Red-Yellow-Green (4 Classes)
# Red-Yellow-Green (5 Classes)
# Red-Yellow-Green (6 Classes)
# Red-Yellow-Green (7 Classes)
# Red-Yellow-Green (8 Classes)
# Red-Yellow-Green (9 Classes)
# Red-Yellow-Green (Continuous)
# Reds
# Reds (3 Classes)
# Reds (4 Classes)
# Reds (5 Classes)
# Reds (6 Classes)
# Reds (7 Classes)
# Reds (8 Classes)
# Reds (9 Classes)
# Reds (Continuous)
# Set 1 (3 Classes)
# Set 1 (4 Classes)
# Set 1 (5 Classes)
# Set 1 (6 Classes)
# Set 1 (7 Classes)
# Set 1 (8 Classes)
# Set 1 (9 Classes)
# Set 2 (3 Classes)
# Set 2 (4 Classes)
# Set 2 (5 Classes)
# Set 2 (6 Classes)
# Set 2 (7 Classes)
# Set 2 (8 Classes)
# Set 3 (10 Classes)
# Set 3 (11 Classes)
# Set 3 (12 Classes)
# Set 3 (3 Classes)
# Set 3 (4 Classes)
# Set 3 (5 Classes)
# Set 3 (6 Classes)
# Set 3 (7 Classes)
# Set 3 (8 Classes)
# Set 3 (9 Classes)
# Shadow to Sunshine
# Slope
# Spectral (10 Classes)
# Spectral (11 Classes)
# Spectral (3 Classes)
# Spectral (4 Classes)
# Spectral (5 Classes)
# Spectral (6 Classes)
# Spectral (7 Classes)
# Spectral (8 Classes)
# Spectral (9 Classes)
# Spectral (Continuous)
# Spectrum By Wavelength-Full Bright
# Spectrum By Wavelength-Full Dark
# Spectrum By Wavelength-Full Light
# Spectrum-Full Bright
# Spectrum-Full Dark
# Spectrum-Full Light
# Surface
# Temperature
# Terra Tones
# Verdant Tones
# Viridis
# Voxel Sequential
# Voxel Unique Values
# Warm Grey
# Warm Grey Shade
# Warm Light Grey Shade
# Warm Purple Grey Shade
# Warm Tones
# Warm Yellow Shade
# White to Black
# Yellow Greens
# Yellow to Red
# Yellow-Blue-Black 2x2
# Yellow-Blue-Black 3x3
# Yellow-Blue-Black 4x4
# Yellow-Cyan-Blue 2x2
# Yellow-Cyan-Blue 3x3
# Yellow-Cyan-Blue 4x4
# Yellow-Green (3 Classes)
# Yellow-Green (4 Classes)
# Yellow-Green (5 Classes)
# Yellow-Green (6 Classes)
# Yellow-Green (7 Classes)
# Yellow-Green (8 Classes)
# Yellow-Green (9 Classes)
# Yellow-Green (Continuous)
# Yellow-Green-Blue (3 Classes)
# Yellow-Green-Blue (4 Classes)
# Yellow-Green-Blue (5 Classes)
# Yellow-Green-Blue (6 Classes)
# Yellow-Green-Blue (7 Classes)
# Yellow-Green-Blue (8 Classes)
# Yellow-Green-Blue (9 Classes)
# Yellow-Green-Blue (Continuous)
# Yellow-Orange-Brown (3 Classes)
# Yellow-Orange-Brown (4 Classes)
# Yellow-Orange-Brown (5 Classes)
# Yellow-Orange-Brown (6 Classes)
# Yellow-Orange-Brown (7 Classes)
# Yellow-Orange-Brown (8 Classes)
# Yellow-Orange-Brown (9 Classes)
# Yellow-Orange-Brown (Continuous)
# Yellow-Orange-Red (3 Classes)
# Yellow-Orange-Red (4 Classes)
# Yellow-Orange-Red (5 Classes)
# Yellow-Orange-Red (6 Classes)
# Yellow-Orange-Red (7 Classes)
# Yellow-Orange-Red (8 Classes)
# Yellow-Orange-Red (9 Classes)
# Yellow-Orange-Red (Continuous)
# Yellows

# %%
busRouteLyrSym.updateRenderer('UniqueValueRenderer')
busRouteLyrSym.renderer.fields = ["PUB_RTE"]
print(busRouteLyrSym.renderer.fields)
busRouteLyrSym.renderer.colorRamp = project.listColorRamps("Basic Random")[0]
busRouteLyr.symbology = busRouteLyrSym
# Out:
# ['PUB_RTE']

# %%
censusLyrSym.updateRenderer('GraduatedColorsRenderer')
print(censusLyrSym.renderer.type)
censusLyrSym.renderer.classificationField = "percent_minority"
print(censusLyrSym.renderer.classificationField)
censusLyrSym.renderer.breakCount = 4
censusLyrSym.renderer.colorRamp = project.listColorRamps('Condition Number')[0]
censusLyr.symbology = censusLyrSym
# Out:
# GraduatedColorsRenderer
# percent_minority

# %%
print(censusLyrSym.renderer.classificationMethod)
# Out:
# NaturalBreaks

# %%
breakValue = 25
firstVal = 0
for brk in censusLyrSym.renderer.classBreaks:
    brk.upperBound = breakValue
    brk.label = "{0} - {1}".format(str(firstVal),str(breakValue))
    breakValue += 25
    firstVal += 25
censusLyr.symbology = censusLyrSym
censusLyr.transparency = 40

# %%
print(censusLyrSym.renderer.classificationMethod)
# Out:
# ManualInterval

# %%
vegLyrSym.updateColorizer("RasterUniqueValueColorizer")
print(vegLyrSym.colorizer.type)
vegLyrSym.colorizer.field = "WHR10NAME"
vegLyrSym.colorizer.colorRamp = project.listColorRamps("Basic Random")[0]
vegLyr.symbology = vegLyrSym
# Out:
# RasterUniqueValueColorizer

# %%
for group in vegLyrSym.colorizer.groups:
    for item in group.items:
        if item.label == "Water":
            item.color = {'RGB' : [0, 0, 255,100]}
        elif item.label == "Urban":
            item.color = {'RGB' : [153, 153, 153,100]}
vegLyr.symbology = vegLyrSym

# %%
project.save()
del project

# %% [markdown]
# ## Welcome to your notebook.

# %% [markdown]
# #### Run this cell to connect to your GIS and get started:

# %%
import time, csv, os
from arcgis.gis import GIS
gis = GIS("home")

# %%
def createCSV(data, csvName, mode = 'w'):
    with open(csvName, mode, newline = '') as csvfile:
        csvwriter = csv.writer(csvfile)
        csvwriter.writerow(data)

# %%
csvPath = r'C:\PythonBook\Chapter11'
csvHeaders = [
    'itemId', 'itemName', 'itemSize_MB', 'lastModified', 
    'NumberOfViews', 'LastViewDate'
]

# %% [markdown]
# To fix below I need to do the following
# 1. Cut the userFullName to print(userFullName) and put in the next cell below print(user)
# 2. Cut itmes = user.items(max_items = 10000) and put below the code block I pasted above
# 3. Change the input paramater from user to items
# 4. In the cell below change the input to the userStorage function to items
# 5. In the cell below create a variable to hold the folders called folders = user.folders
# 6. In the cell below loop through the folders list with for folder in folders: and then create variable folder_items = user.items(folder=folder,max_items=10000)
# 7. In the loop above send folder_items to the userStorage function.
#
# Then open up and rewrite this section of the chapter in track changes.

# %%
def userStorage(item):
    for item in items:
        itemId = item.id
        print(itemId)
        itemName = item.title
        print(itemName)
        print(item.size)
        itemSize = round(item.size/1000000,3)
        print(itemSize)
        lastMod = time.localtime(int(item.modified)/1000)
        lastModDate = '{0}/{1}/{2}'.format(
            lastMod[1], lastMod[2], lastMod[0])
        print(lastModDate)
        itemType = item.type
        print(itemType)    
        numbViews = item.numViews
        print(numbViews)
        itemUsage = item.usage('1Y',False)
        #print(itemUsage)
        viewDate = 0
        for usage in itemUsage:
            if len(usage['data']) > 0:
                #print(usage['data'])
                listNumViews = usage['data'][0]['num']
                #print(listNumViews)
                for views in listNumViews:
                    #print(views)
                    if int(views[1]) > 0:
                        print(views)
                        newViewDate = int(views[0])
                        if newViewDate > viewDate:
                            viewDate=newViewDate

        lastView = time.localtime(viewDate/1000)
        lastViewDate = '{0}/{1}/{2}'.format(lastView[1],lastView[2],lastView[0])
        print(lastViewDate)
        itemList = [
            itemId, itemName, itemSize, lastModDate, numbViews, 
            lastViewDate, itemType
        ]
        createCSV(itemList, csvFull, mode = 'a')

# %%
users = gis.users.search(query='username:billparkermapping')
for user in users:
    print(user)
    userFullName = user.fullName
    userName = user.username
    print(userFullName)
    #print(userName)
    items = user.items(max_items=10000)
    csvFull = os.path.join(
        csvPath,'{0}_data4.csv'.format(
            user.username.replace('.','_')
        )
    )
    createCSV(csvHeaders, csvFull, mode = 'w')
    userStorage(items)
    print(len(items))
    folders = user.folders
#     for folder in folders:
#         print(folder)
#         folder_items = user.items(
#             folder=folder, max_items=10000)
#         userStorage(folder_items)
# Out:
# <User username:billparkermapping>
# Bill Parker
# 6c7d00d2be7844f49a75b2780992299d
# Farmers Markets
# 7539
# 0.008
# 8/11/2021
# Dashboard
# 1
# ['1628726400000', '1']
# 8/11/2021
# 674b4c2835984d2da04ec22b57a8e116
# AdditionalAlamedaFarmersMarket_Test2
# 264367
# 0.264
# 10/27/2021
# File Geodatabase
# 1
# ['1635379200000', '1']
# 10/27/2021
# 109ea42b13e74e758d92ab65e388e8ed
# AdditionalAlamedaFarmersMarket_Test2
# 32768
# 0.033
# 10/27/2021
# Feature Service
# 6
# ['1635379200000', '23']
# ['1636502400000', '3']
# ['1639008000000', '2']
# ['1641427200000', '4']
# ['1641772800000', '5']
# ['1650326400000', '1']
# ['1650412800000', '1']
# 4/19/2022
# d8dbf13b9bce4f1e9c3d8d346e295ac3
# Farmers Markets in Alameda County 3
# 1133
# 0.001
# 11/23/2021
# CSV
# 3
# ['1637712000000', '3']
# 11/23/2021
# 267bb8b8f1d4403abcd9cd22e9617e92
# Farmers Markets in Alameda County
# 32768
# 0.033
# 1/5/2022
# Feature Service
# 16
# ['1637712000000', '27']
# ['1639180800000', '2']
# ['1641427200000', '115']
# ['1641772800000', '9']
# ['1642464000000', '20']
# ['1650326400000', '1']
# ['1650412800000', '1']
# 4/19/2022
# d360303989ca4527b1f9e2f1750aac89
# AlamedaContraCostaBlockGroupBus_FarmersMarket
# 6665912
# 6.666
# 1/11/2022
# Service Definition
# 1
# ['1641945600000', '1']
# 1/11/2022
# d65243d3a8fa475aa16ac163336615bd
# AlamedaContraCostaBlockGroupBus_FarmersMarket
# 15269888
# 15.27
# 1/11/2022
# Feature Service
# 4
# ['1641945600000', '9']
# ['1650326400000', '1']
# 4/18/2022
# {'username': 'billparkermapping', 'id': 'bcd0dad584604adb95dc781cb039d93a', 'title': 'AlamedaFarmersMarkets', 'created': 1627849261000}
# 6c7d00d2be7844f49a75b2780992299d
# Farmers Markets
# 7539
# 0.008
# 8/11/2021
# Dashboard
# 1
# ['1628726400000', '1']
# 8/11/2021
# 674b4c2835984d2da04ec22b57a8e116
# AdditionalAlamedaFarmersMarket_Test2
# 264367
# 0.264
# 10/27/2021
# File Geodatabase
# 1
# ['1635379200000', '1']
# 10/27/2021
# 109ea42b13e74e758d92ab65e388e8ed
# AdditionalAlamedaFarmersMarket_Test2
# 32768
# 0.033
# 10/27/2021
# Feature Service
# 6
# ['1635379200000', '23']
# ['1636502400000', '3']
# ['1639008000000', '2']
# ['1641427200000', '4']
# ['1641772800000', '5']
# ['1650326400000', '1']
# ['1650412800000', '1']
# 4/19/2022
# d8dbf13b9bce4f1e9c3d8d346e295ac3
# Farmers Markets in Alameda County 3
# 1133
# 0.001
# 11/23/2021
# CSV
# 3
# ['1637712000000', '3']
# 11/23/2021
# 267bb8b8f1d4403abcd9cd22e9617e92
# Farmers Markets in Alameda County
# 32768
# 0.033
# 1/5/2022
# Feature Service
# 16
# ['1637712000000', '27']
# ['1639180800000', '2']
# ['1641427200000', '115']
# ['1641772800000', '9']
# ['1642464000000', '20']
# ['1650326400000', '1']
# ['1650412800000', '1']
# 4/19/2022
# d360303989ca4527b1f9e2f1750aac89
# AlamedaContraCostaBlockGroupBus_FarmersMarket
# 6665912
# 6.666
# 1/11/2022
# Service Definition
# 1
# ['1641945600000', '1']
# 1/11/2022
# d65243d3a8fa475aa16ac163336615bd
# AlamedaContraCostaBlockGroupBus_FarmersMarket
# 15269888
# 15.27
# 1/11/2022
# Feature Service
# 4
# ['1641945600000', '9']
# ['1650326400000', '1']
# 4/18/2022
# {'username': 'billparkermapping', 'id': '4303f7d922ff488ca67ef0444f85efb4', 'title': 'Survey-Alameda County Farmers Market', 'created': 1627362483000}
# 6c7d00d2be7844f49a75b2780992299d
# Farmers Markets
# 7539
# 0.008
# 8/11/2021
# Dashboard
# 1
# ['1628726400000', '1']
# 8/11/2021
# 674b4c2835984d2da04ec22b57a8e116
# AdditionalAlamedaFarmersMarket_Test2
# 264367
# 0.264
# 10/27/2021
# File Geodatabase
# 1
# ['1635379200000', '1']
# 10/27/2021
# 109ea42b13e74e758d92ab65e388e8ed
# AdditionalAlamedaFarmersMarket_Test2
# 32768
# 0.033
# 10/27/2021
# Feature Service
# 6
# ['1635379200000', '23']
# ['1636502400000', '3']
# ['1639008000000', '2']
# ['1641427200000', '4']
# ['1641772800000', '5']
# ['1650326400000', '1']
# ['1650412800000', '1']
# 4/19/2022
# d8dbf13b9bce4f1e9c3d8d346e295ac3
# Farmers Markets in Alameda County 3
# 1133
# 0.001
# 11/23/2021
# CSV
# 3
# ['1637712000000', '3']
# 11/23/2021
# 267bb8b8f1d4403abcd9cd22e9617e92
# Farmers Markets in Alameda County
# 32768
# 0.033
# 1/5/2022
# Feature Service
# 16
# ['1637712000000', '27']
# ['1639180800000', '2']
# ['1641427200000', '115']
# ['1641772800000', '9']
# ['1642464000000', '20']
# ['1650326400000', '1']
# ['1650412800000', '1']
# 4/19/2022
# d360303989ca4527b1f9e2f1750aac89
# AlamedaContraCostaBlockGroupBus_FarmersMarket
# 6665912
# 6.666
# 1/11/2022
# Service Definition
# 1
# ['1641945600000', '1']
# 1/11/2022
# d65243d3a8fa475aa16ac163336615bd
# AlamedaContraCostaBlockGroupBus_FarmersMarket
# 15269888
# 15.27
# 1/11/2022
# Feature Service
# 4
# ['1641945600000', '9']
# ['1650326400000', '1']
# 4/18/2022
